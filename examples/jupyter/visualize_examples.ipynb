# %%
# %matplotlib inline
from glob import glob
from ef.config.visualizer import Visualizer3d
from ef.config.config import Config
example_configs = glob('../*/*.conf')
for fname in example_configs:
    print(fname)
    Config.from_fname(fname).visualize_all(Visualizer3d())
# Out:
# No handles with labels found to put in legend.
# ../minimal_working_example/minimal_conf.conf
# ../drift_tube_potential/pot.conf
# ../run_hydra_gpu_example/contour.conf
# ../ribbon_beam_contour/contour.conf
# ../ribbon_beam_contour/contour_bin.conf
# ../axially_symmetric_beam_contour/contour.conf
# ../tsi/tsi-short-time-coarse.conf
# ../tsi/tsi-short-time-coarse-ish.conf
# ../tsi/tsi-short-time.conf
# ../tsi/tsi.conf
# ../tsi/tsi-binary.conf
# ../tsi/tsi-short-time-binary.conf
# ../single_particle_in_free_space/single_particle_in_free_space.conf
# ../tube_source_test/contour.conf
# ../single_particle_in_radial_electric_field/single_particle_in_radial_electric_field.conf
# ../single_particle_in_magnetic_field/long_simulation_time.conf
# ../single_particle_in_magnetic_field/single_particle_in_magnetic_field.conf
# ../single_particle_in_magnetic_field/large_time_step.conf

# %%
# %matplotlib inline
import numpy as np
from ef.config.visualizer import Visualizer3d

v = Visualizer3d()
v.draw_tube(np.array((1, 1, 1)), np.array((5, 8, 7)), 2, 3, facecolors='r', edgecolors='k')
v.draw_cylinder(np.array((1, 7, 7)), np.array((5, 3, 2)), 1, facecolors='y', edgecolors='k')
v.draw_box(np.array((5, 2, 2)), np.array((3, 3, 5)), facecolors='g', edgecolors='k')
v.draw_sphere(np.array((8, 8, 3)), 2, facecolors='navy', edgecolors='k')
v.draw_tube(np.array((3, 1, 2)), np.array((7, 8, 7)), 1, 3, color='cyan', wireframe=False)
v.draw_cylinder(np.array((8, 7, 7)), np.array((5, 3, 8)), 4, wireframe=True)
v.draw_box(np.array((10, 10, 10)), np.array((0, 0, 0)), colors='k', wireframe=True)
v.draw_sphere(np.array((8, 3, 3)), 2, colors='purple', wireframe=True)
v.draw_cone(np.array((4, 5, 8)), np.array((12, 8, 10)),np.array((1,2)), np.array((3,4)), color='orange', wireframe=False)
v.show()
# Out:
# No handles with labels found to put in legend.
