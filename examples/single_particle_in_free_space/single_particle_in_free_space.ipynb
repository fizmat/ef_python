# %% [markdown]
# Dynamics of a single particle in free space is the simplest kind of simulation. It allows to check basic functionality of the program, and, besides, it is a good way to become familiar with how the program works.

# %% [markdown]
# In absence of external forces, a body moves in straight line with constant velocity
#
# \begin{align}
# & \textbf{r}(t) = \textbf{r}_0 + \textbf{v}_0 t
# \\
# & \textbf{v}(t) = \textbf{v}_0
# \end{align}

# %% [markdown]
# To get some sense of scales (see below), suppose the particle is an electron that has just passed an 1 keV accelerating potential difference. Its mass `m` and charge `q` are `q = 4.8e-10 [cgs], m = 9.1e-28 [g]`. Since its energy is nonrelativistic, it's possible to calculate its speed simply as $v = \sqrt{ 2 E / m } = 1.808e+09 ~ [cm/s]$. To cover a `10 [cm]` distance with such speed, it will take the electron `t = 5.530e-09 [s] ~ 6 [ns]`.

# %%
#estimates

from math import *

m = 9.8e-28
q = 4.8e-10
print("q = {:.3e} [cgs]".format(q))
print("m = {:.3e} [g]".format(m))

ev_to_cgs = 1.60218e-12
E = 1000 * ev_to_cgs
v = sqrt(2 * E / m)
print("E = {:.3e} [eV] = {:.3e} [erg]".format(E / ev_to_cgs, E))
print("v = {:.3e} [cm/s]".format(v))
print("p = {:.3e} [g * cm/s]".format(v * m))

z_distance = 10
t = z_distance / v
print("z_distance = {:f} [cm]".format(z_distance))
print("t = {:.3e} [s]".format(t))

sim_time = 6.0e-9
n_of_steps = 1000
dt = sim_time / n_of_steps
print("simulation_time = {:.3e} [s]".format(sim_time))
print("number_of_time_steps = {:d}".format(n_of_steps))
print("time_step_size = {:.3e} [s]".format(dt))
# Out:
# q = 4.800e-10 [cgs]
# m = 9.800e-28 [g]
# E = 1.000e+03 [eV] = 1.602e-09 [erg]
# v = 1.808e+09 [cm/s]
# p = 1.772e-18 [g * cm/s]
# z_distance = 10.000000 [cm]
# t = 5.530e-09 [s]
# simulation_time = 6.000e-09 [s]
# number_of_time_steps = 1000
# time_step_size = 6.000e-12 [s]

# %%
from math import *

m = 9.8e-28
q = 4.8e-10
print( "q = {:.3e} [cgs]".format( q ) )
print( "m = {:.3e} [g]".format( m ) )

ev_to_cgs = 1.60218e-12
E = 1000 * ev_to_cgs
v = sqrt( 2 * E / m )
z = 10
t = z / v
print( "E = {:.3e} [eV] = {:.3e} [erg]".format( E / ev_to_cgs, E ) )
print( "v = {:.3e} [cm/s]; p = {:.3e} [g * cm/s]".format( v, v * m ) )
print( "z = {:.3e} [cm]".format( z ) )
print( "t = {:.3e} [s]".format( t ) )
# Out:
# q = 4.800e-10 [cgs]
# m = 9.800e-28 [g]
# E = 1.000e+03 [eV] = 1.602e-09 [erg]
# v = 1.808e+09 [cm/s]; p = 1.772e-18 [g * cm/s]
# z = 1.000e+01 [cm]
# t = 5.530e-09 [s]

# %% [markdown]
# To perform a simulation, it's necessary to prepare a config file. It is an `ini`-file with sections describing the simulation parameters, e.g.:
#
# ```
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-12
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5.0
# grid_x_step = 0.5
# grid_y_size = 5.0
# grid_y_step = 0.5
# grid_z_size = 15.0
# grid_z_step = 1.5
#
# [ParticleSourceBox.emit_single_particle]
# box_x_left = 0.11
# box_x_right = 0.1
# ...
# ```
# If Ef is invoked from the command line, this file is passed as an argument:
#
# ```
# ef conf.ini
# ```
#
# The list of supported config sections can be found in the wiki: https://github.com/epicf/ef/wiki/Supported-Config-File-Sections .

# %% [markdown]
# Config classes can be used to create, visualize and read/write to ini the config file with python or jupyter.

# %%
from ef.config.components import *
from ef.config.config import Config
from ef.config.visualizer import Visualizer3d
Visualizer3d()

# %% [markdown]
# First, it's necessary to set a total time of the simulation and a time step.
# Let's use the estimates above as guiding values and set the total time to `6e-9 [s]`.
# We use `1000` time steps, so that `time_step_size = 6.0e-12 [s]`.
# Besides, it's necessary to decide at which time steps the state of the whole simulation should be saved to the disk.
# To save each tenth step, `time_save_step` is set equal to 10x of `time_step_size`: `time_save_step = 6.0e-11`.

# %%
single_particle_in_free_space_conf = ""

time_grid_sec = """
[TimeGrid]
total_time = 6e-09
time_save_step = 6e-11
time_step_size = 6e-12
"""

single_particle_in_free_space_conf = single_particle_in_free_space_conf + time_grid_sec

print( single_particle_in_free_space_conf )
# Out:
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12

# %%
timegrid = TimeGridConf(total=6e-09, save_step=6e-11, step=6e-12)
print(repr(timegrid))
print(timegrid)
# Out:
# TimeGridConf(total=6e-09, save_step=6e-11, step=6e-12)
# ### TimeGridConf:
# total = 6e-09
# save_step = 6e-11
# step = 6e-12

# %% [markdown]
# Next we need to define size of a computational volume.
# Domain size is set to 15 [cm] along the z-axis and 5 [cm] along the x- and y-axes.
# The parameters for PIC-mesh are also defined in this section.
# Since we are going to use noninteracting particle model instead of PIC, they are not used and can be set arbitrary.

# %%
spat_mesh_sec = """
[SpatialMesh]
grid_x_size = 5.0
grid_x_step = 0.5
grid_y_size = 5.0
grid_y_step = 0.5
grid_z_size = 15.0
grid_z_step = 1.5
"""

single_particle_in_free_space_conf = single_particle_in_free_space_conf + spat_mesh_sec

print( single_particle_in_free_space_conf )
# Out:
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5.0
# grid_x_step = 0.5
# grid_y_size = 5.0
# grid_y_step = 0.5
# grid_z_size = 15.0
# grid_z_step = 1.5

# %%
mesh = SpatialMeshConf((5, 5, 15), (.5, .5, 1.5))
print(repr(mesh))
print(mesh)
Visualizer3d().visualize([mesh])
# Out:
# SpatialMeshConf(size=array([ 5,  5, 15]), step=array([0.5, 0.5, 1.5]))
# ### SpatialMeshConf:
# size = array([ 5,  5, 15])
# step = array([0.5, 0.5, 1.5])

# %% [markdown]
# Next, a particle source.
# We need a single particle at startup ( `initial_number_of_particles = 1` ), approximately 1 [mm] away from
# coordinate axis origin at the bottom-left-near corner of the domain (`shape = Box( origin = (0.1, ...` below and `box_x_left = 0.10 ...` in the ini-version).
# Charge and mass are set to those of the electron.
# Momentum corresponding to 1 keV energy is `1.772e-18 [g * cm / s]`.
# Such value is set for momentum along the z-axis.
# Momenta along the x- and y-axes could be set to zero; instead they are chosen 3 times smaller than the z-axis momentum
# (domain size along the x and y is 3 times smaller than along the z).
# To prevent any variation in momentum, the `temperature` is set to 0.
# Notice that the source is given a descriptive name: `emit_single_particle` in this case.

# %%
emit_single_particle_sec = """
[ParticleSourceBox.emit_single_particle]
box_x_left = 0.11
box_x_right = 0.1
box_y_bottom = 0.1
box_y_top = 0.11
box_z_near = 0.1
box_z_far = 0.11
initial_number_of_particles = 1
particles_to_generate_each_step = 0
mean_momentum_x = 6e-19
mean_momentum_y = 6e-19
mean_momentum_z = 1.77e-18
temperature = 0.0
charge = 4.8e-10
mass = 9.8e-28
"""

single_particle_in_free_space_conf = single_particle_in_free_space_conf + emit_single_particle_sec

print( single_particle_in_free_space_conf )
# Out:
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5.0
# grid_x_step = 0.5
# grid_y_size = 5.0
# grid_y_step = 0.5
# grid_z_size = 15.0
# grid_z_step = 1.5
#
# [ParticleSourceBox.emit_single_particle]
# box_x_left = 0.11
# box_x_right = 0.1
# box_y_bottom = 0.1
# box_y_top = 0.11
# box_z_near = 0.1
# box_z_far = 0.11
# initial_number_of_particles = 1
# particles_to_generate_each_step = 0
# mean_momentum_x = 6e-19
# mean_momentum_y = 6e-19
# mean_momentum_z = 1.77e-18
# temperature = 0.0
# charge = 4.8e-10
# mass = 9.8e-28

# %%
source = ParticleSourceConf("emit_single_particle", Box((.1, .1, .1), (.01, .01, .01)), 1, 0,
                           (6e-19, 6e-19, 1.77e-18), 0., 4.8e-10, 9.8e-28)
print(repr(source))
print(source)
Visualizer3d().visualize([mesh, source]) # small dot near (0, 0, 0) because mesh is so big
# Out:
# ParticleSourceConf(name='emit_single_particle', shape=Box(origin=array([0.1, 0.1, 0.1]), size=array([0.01, 0.01, 0.01])), initial_particles=1, particles_to_generate_each_step=0, momentum=array([6.00e-19, 6.00e-19, 1.77e-18]), temperature=0.0, charge=4.8e-10, mass=9.8e-28)
# ### ParticleSourceConf:
# name = 'emit_single_particle'
# shape = Box(origin=array([0.1, 0.1, 0.1]), size=array([0.01, 0.01, 0.01]))
# initial_particles = 1
# particles_to_generate_each_step = 0
# momentum = array([6.00e-19, 6.00e-19, 1.77e-18])
# temperature = 0.0
# charge = 4.8e-10
# mass = 9.8e-28

# %% [markdown]
# Next section is boundary conditions.
# In a free space, potentials on each boundary should be equal.
# It is possible to simply set them to zero.

# %%
boundary_sec = """
[BoundaryConditions]
boundary_phi_right = 0.0
boundary_phi_left = 0.0
boundary_phi_bottom = 0.0
boundary_phi_top = 0.0
boundary_phi_near = 0.0
boundary_phi_far = 0.0
"""

single_particle_in_free_space_conf = single_particle_in_free_space_conf + boundary_sec

print( single_particle_in_free_space_conf )
# Out:
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5.0
# grid_x_step = 0.5
# grid_y_size = 5.0
# grid_y_step = 0.5
# grid_z_size = 15.0
# grid_z_step = 1.5
#
# [ParticleSourceBox.emit_single_particle]
# box_x_left = 0.11
# box_x_right = 0.1
# box_y_bottom = 0.1
# box_y_top = 0.11
# box_z_near = 0.1
# box_z_far = 0.11
# initial_number_of_particles = 1
# particles_to_generate_each_step = 0
# mean_momentum_x = 6e-19
# mean_momentum_y = 6e-19
# mean_momentum_z = 1.77e-18
# temperature = 0.0
# charge = 4.8e-10
# mass = 9.8e-28
#
# [BoundaryConditions]
# boundary_phi_right = 0.0
# boundary_phi_left = 0.0
# boundary_phi_bottom = 0.0
# boundary_phi_top = 0.0
# boundary_phi_near = 0.0
# boundary_phi_far = 0.0

# %%
boundary_conditions = BoundaryConditionsConf(0)
print(repr(boundary_conditions))
print(boundary_conditions)
# Out:
# BoundaryConditionsConf(right=0.0, left=0.0, bottom=0.0, top=0.0, near=0.0, far=0.0)
# ### BoundaryConditionsConf:
# right = 0.0
# left = 0.0
# bottom = 0.0
# top = 0.0
# near = 0.0
# far = 0.0

# %% [markdown]
# Particle interaction model allows to choose between noninteracting particles, particle interacting with binary forces and PIC method. Since there is only one particle, there is no need to use PIC, and noninteracting mode is enough. Moreover, PIC will lead to wrong results (because particle creates electric field that acts back on the particle).

# %%
particle_interaction_model_sec = """
[ParticleInteractionModel]
particle_interaction_model = noninteracting
"""

single_particle_in_free_space_conf = single_particle_in_free_space_conf + particle_interaction_model_sec

print( single_particle_in_free_space_conf )
# Out:
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5.0
# grid_x_step = 0.5
# grid_y_size = 5.0
# grid_y_step = 0.5
# grid_z_size = 15.0
# grid_z_step = 1.5
#
# [ParticleSourceBox.emit_single_particle]
# box_x_left = 0.11
# box_x_right = 0.1
# box_y_bottom = 0.1
# box_y_top = 0.11
# box_z_near = 0.1
# box_z_far = 0.11
# initial_number_of_particles = 1
# particles_to_generate_each_step = 0
# mean_momentum_x = 6e-19
# mean_momentum_y = 6e-19
# mean_momentum_z = 1.77e-18
# temperature = 0.0
# charge = 4.8e-10
# mass = 9.8e-28
#
# [BoundaryConditions]
# boundary_phi_right = 0.0
# boundary_phi_left = 0.0
# boundary_phi_bottom = 0.0
# boundary_phi_top = 0.0
# boundary_phi_near = 0.0
# boundary_phi_far = 0.0
#
# [ParticleInteractionModel]
# particle_interaction_model = noninteracting

# %%
model = ParticleInteractionModelConf('noninteracting')
print(repr(model))
print(model)
# Out:
# ParticleInteractionModelConf(model='noninteracting')
# ### ParticleInteractionModelConf:
# model = 'noninteracting'

# %% [markdown]
# The last step is to specify pattern for output file names.
# They will be of the form `single_particle_free_space_0001000.h5`, where `0001000` is a time step number.

# %%
output_sec = """
[OutputFilename]
output_filename_prefix = single_particle_free_space_
output_filename_suffix = .h5
"""

single_particle_in_free_space_conf = single_particle_in_free_space_conf + output_sec

print( single_particle_in_free_space_conf )
# Out:
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5.0
# grid_x_step = 0.5
# grid_y_size = 5.0
# grid_y_step = 0.5
# grid_z_size = 15.0
# grid_z_step = 1.5
#
# [ParticleSourceBox.emit_single_particle]
# box_x_left = 0.11
# box_x_right = 0.1
# box_y_bottom = 0.1
# box_y_top = 0.11
# box_z_near = 0.1
# box_z_far = 0.11
# initial_number_of_particles = 1
# particles_to_generate_each_step = 0
# mean_momentum_x = 6e-19
# mean_momentum_y = 6e-19
# mean_momentum_z = 1.77e-18
# temperature = 0.0
# charge = 4.8e-10
# mass = 9.8e-28
#
# [BoundaryConditions]
# boundary_phi_right = 0.0
# boundary_phi_left = 0.0
# boundary_phi_bottom = 0.0
# boundary_phi_top = 0.0
# boundary_phi_near = 0.0
# boundary_phi_far = 0.0
#
# [ParticleInteractionModel]
# particle_interaction_model = noninteracting
#
# [OutputFilename]
# output_filename_prefix = single_particle_free_space_
# output_filename_suffix = .h5

# %% [markdown]
# To start the simulation, the config should saved into file and provided as an argument to the `ef.out`, e.g.:
#
# ```
# ef.out ./single_particle_in_free_space_conf.ini
# ```
#
# EfJupyter module provides a wrapper `EfRunner` to do this.

# %%
file_conf = OutputFileConf('single_particle_free_space_', '.h5')
print(repr(file_conf))
print(file_conf)
# Out:
# OutputFileConf(prefix='single_particle_free_space_', suffix='.h5', format_='cpp')
# ### OutputFileConf:
# prefix = 'single_particle_free_space_'
# suffix = '.h5'
# format_ = 'cpp'

# %% [markdown]
# You can check that config objects describe the same simulation:

# %%
conf = Config(timegrid, mesh, [source], [], file_conf, boundary_conditions, model)
print(conf)
print(conf.export_to_string())
conf.visualize_all(Visualizer3d())
# Out:
# ### Config:
# time_grid = TimeGridConf(total=6e-09, save_step=6e-11, step=6e-12)
# spatial_mesh = SpatialMeshConf(size=array([ 5,  5, 15]), step=array([0.5, 0.5, 1.5]))
# sources = [ParticleSourceConf(name='emit_single_particle', shape=Box(origin=array([0.1, 0.1, 0.1]), size=array([0.01, 0.01, 0.01])), initial_particles=1, particles_to_generate_each_step=0, momentum=array([6.00e-19, 6.00e-19, 1.77e-18]), temperature=0.0, charge=4.8e-10, mass=9.8e-28)]
# inner_regions = []
# output_file = OutputFileConf(prefix='single_particle_free_space_', suffix='.h5', format_='cpp')
# boundary_conditions = BoundaryConditionsConf(right=0.0, left=0.0, bottom=0.0, top=0.0, near=0.0, far=0.0)
# particle_interaction_model = ParticleInteractionModelConf(model='noninteracting')
# external_fields = []
# [TimeGrid]
# total_time = 6e-09
# time_save_step = 6e-11
# time_step_size = 6e-12
#
# [SpatialMesh]
# grid_x_size = 5
# grid_y_size = 5
# grid_z_size = 15
# grid_x_step = 0.5
# grid_y_step = 0.5
# grid_z_step = 1.5
#
# [ParticleSourceBox.emit_single_particle]
# box_x_left = 0.11
# box_x_right = 0.1
# box_y_bottom = 0.1
# box_y_top = 0.11
# box_z_near = 0.1
# box_z_far = 0.11
# initial_number_of_particles = 1
# particles_to_generate_each_step = 0
# mean_momentum_x = 6e-19
# mean_momentum_y = 6e-19
# mean_momentum_z = 1.77e-18
# temperature = 0.0
# charge = 4.8e-10
# mass = 9.8e-28
#
# [OutputFilename]
# output_filename_prefix = single_particle_free_space_
# output_filename_suffix = .h5
#
# [BoundaryConditions]
# boundary_phi_right = 0.0
# boundary_phi_left = 0.0
# boundary_phi_bottom = 0.0
# boundary_phi_top = 0.0
# boundary_phi_near = 0.0
# boundary_phi_far = 0.0
#
# [ParticleInteractionModel]
# particle_interaction_model = noninteracting

# %% [markdown]
# To run outside Jupyter just save the config file
#
# -  with any text editor
# -  or with `efconf.export_to_file()`
#
# Run `ef config.ini` in the directory where you want simulation to run and save results.
#
# To run in python from Jupyter:

# %%
from ef.runner import Runner
# if you start from .ini
# conf = Config.from_fname('config.ini')
sim = conf.make()
Runner(sim, output_writer=conf.output_file.make()).start()
# Out:
#   Detected a Hermitian matrix
# Writing initial fields to file
# Writing to file single_particle_free_space_fieldsWithoutParticles.h5
# Writing step 0 to file
# Writing to file single_particle_free_space_0000000.h5
# Time step from 9 to 10 of 1000
# Writing step 10 to file
# Writing to file single_particle_free_space_0000010.h5
# Time step from 19 to 20 of 1000
# Writing step 20 to file
# Writing to file single_particle_free_space_0000020.h5
# Time step from 29 to 30 of 1000
# Writing step 30 to file
# Writing to file single_particle_free_space_0000030.h5
# Time step from 39 to 40 of 1000
# Writing step 40 to file
# Writing to file single_particle_free_space_0000040.h5
# Time step from 49 to 50 of 1000
# Writing step 50 to file
# Writing to file single_particle_free_space_0000050.h5
# Time step from 59 to 60 of 1000
# Writing step 60 to file
# Writing to file single_particle_free_space_0000060.h5
# Time step from 69 to 70 of 1000
# Writing step 70 to file
# Writing to file single_particle_free_space_0000070.h5
# Time step from 79 to 80 of 1000
# Writing step 80 to file
# Writing to file single_particle_free_space_0000080.h5
# Time step from 89 to 90 of 1000
# Writing step 90 to file
# Writing to file single_particle_free_space_0000090.h5
# Time step from 99 to 100 of 1000
# Writing step 100 to file
# Writing to file single_particle_free_space_0000100.h5
# Time step from 109 to 110 of 1000
# Writing step 110 to file
# Writing to file single_particle_free_space_0000110.h5
# Time step from 119 to 120 of 1000
# Writing step 120 to file
# Writing to file single_particle_free_space_0000120.h5
# Time step from 129 to 130 of 1000
# Writing step 130 to file
# Writing to file single_particle_free_space_0000130.h5
# Time step from 139 to 140 of 1000
# Writing step 140 to file
# Writing to file single_particle_free_space_0000140.h5
# Time step from 149 to 150 of 1000
# Writing step 150 to file
# Writing to file single_particle_free_space_0000150.h5
# Time step from 159 to 160 of 1000
# Writing step 160 to file
# Writing to file single_particle_free_space_0000160.h5
# Time step from 169 to 170 of 1000
# Writing step 170 to file
# Writing to file single_particle_free_space_0000170.h5
# Time step from 179 to 180 of 1000
# Writing step 180 to file
# Writing to file single_particle_free_space_0000180.h5
# Time step from 189 to 190 of 1000
# Writing step 190 to file
# Writing to file single_particle_free_space_0000190.h5
# Time step from 199 to 200 of 1000
# Writing step 200 to file
# Writing to file single_particle_free_space_0000200.h5
# Time step from 209 to 210 of 1000
# Writing step 210 to file
# Writing to file single_particle_free_space_0000210.h5
# Time step from 219 to 220 of 1000
# Writing step 220 to file
# Writing to file single_particle_free_space_0000220.h5
# Time step from 229 to 230 of 1000
# Writing step 230 to file
# Writing to file single_particle_free_space_0000230.h5
# Time step from 239 to 240 of 1000
# Writing step 240 to file
# Writing to file single_particle_free_space_0000240.h5
# Time step from 249 to 250 of 1000
# Writing step 250 to file
# Writing to file single_particle_free_space_0000250.h5
# Time step from 259 to 260 of 1000
# Writing step 260 to file
# Writing to file single_particle_free_space_0000260.h5
# Time step from 269 to 270 of 1000
# Writing step 270 to file
# Writing to file single_particle_free_space_0000270.h5
# Time step from 279 to 280 of 1000
# Writing step 280 to file
# Writing to file single_particle_free_space_0000280.h5
# Time step from 289 to 290 of 1000
# Writing step 290 to file
# Writing to file single_particle_free_space_0000290.h5
# Time step from 299 to 300 of 1000
# Writing step 300 to file
# Writing to file single_particle_free_space_0000300.h5
# Time step from 309 to 310 of 1000
# Writing step 310 to file
# Writing to file single_particle_free_space_0000310.h5
# Time step from 319 to 320 of 1000
# Writing step 320 to file
# Writing to file single_particle_free_space_0000320.h5
# Time step from 329 to 330 of 1000
# Writing step 330 to file
# Writing to file single_particle_free_space_0000330.h5
# Time step from 339 to 340 of 1000
# Writing step 340 to file
# Writing to file single_particle_free_space_0000340.h5
# Time step from 349 to 350 of 1000
# Writing step 350 to file
# Writing to file single_particle_free_space_0000350.h5
# Time step from 359 to 360 of 1000
# Writing step 360 to file
# Writing to file single_particle_free_space_0000360.h5
# Time step from 369 to 370 of 1000
# Writing step 370 to file
# Writing to file single_particle_free_space_0000370.h5
# Time step from 379 to 380 of 1000
# Writing step 380 to file
# Writing to file single_particle_free_space_0000380.h5
# Time step from 389 to 390 of 1000
# Writing step 390 to file
# Writing to file single_particle_free_space_0000390.h5
# Time step from 399 to 400 of 1000
# Writing step 400 to file
# Writing to file single_particle_free_space_0000400.h5
# Time step from 409 to 410 of 1000
# Writing step 410 to file
# Writing to file single_particle_free_space_0000410.h5
# Time step from 419 to 420 of 1000
# Writing step 420 to file
# Writing to file single_particle_free_space_0000420.h5
# Time step from 429 to 430 of 1000
# Writing step 430 to file
# Writing to file single_particle_free_space_0000430.h5
# Time step from 439 to 440 of 1000
# Writing step 440 to file
# Writing to file single_particle_free_space_0000440.h5
# Time step from 449 to 450 of 1000
# Writing step 450 to file
# Writing to file single_particle_free_space_0000450.h5
# Time step from 459 to 460 of 1000
# Writing step 460 to file
# Writing to file single_particle_free_space_0000460.h5
# Time step from 469 to 470 of 1000
# Writing step 470 to file
# Writing to file single_particle_free_space_0000470.h5
# Time step from 479 to 480 of 1000
# Writing step 480 to file
# Writing to file single_particle_free_space_0000480.h5
# Time step from 489 to 490 of 1000
# Writing step 490 to file
# Writing to file single_particle_free_space_0000490.h5
# Time step from 499 to 500 of 1000
# Writing step 500 to file
# Writing to file single_particle_free_space_0000500.h5
# Time step from 509 to 510 of 1000
# Writing step 510 to file
# Writing to file single_particle_free_space_0000510.h5
# Time step from 519 to 520 of 1000
# Writing step 520 to file
# Writing to file single_particle_free_space_0000520.h5
# Time step from 529 to 530 of 1000
# Writing step 530 to file
# Writing to file single_particle_free_space_0000530.h5
# Time step from 539 to 540 of 1000
# Writing step 540 to file
# Writing to file single_particle_free_space_0000540.h5
# Time step from 549 to 550 of 1000
# Writing step 550 to file
# Writing to file single_particle_free_space_0000550.h5
# Time step from 559 to 560 of 1000
# Writing step 560 to file
# Writing to file single_particle_free_space_0000560.h5
# Time step from 569 to 570 of 1000
# Writing step 570 to file
# Writing to file single_particle_free_space_0000570.h5
# Time step from 579 to 580 of 1000
# Writing step 580 to file
# Writing to file single_particle_free_space_0000580.h5
# Time step from 589 to 590 of 1000
# Writing step 590 to file
# Writing to file single_particle_free_space_0000590.h5
# Time step from 599 to 600 of 1000
# Writing step 600 to file
# Writing to file single_particle_free_space_0000600.h5
# Time step from 609 to 610 of 1000
# Writing step 610 to file
# Writing to file single_particle_free_space_0000610.h5
# Time step from 619 to 620 of 1000
# Writing step 620 to file
# Writing to file single_particle_free_space_0000620.h5
# Time step from 629 to 630 of 1000
# Writing step 630 to file
# Writing to file single_particle_free_space_0000630.h5
# Time step from 639 to 640 of 1000
# Writing step 640 to file
# Writing to file single_particle_free_space_0000640.h5
# Time step from 649 to 650 of 1000
# Writing step 650 to file
# Writing to file single_particle_free_space_0000650.h5
# Time step from 659 to 660 of 1000
# Writing step 660 to file
# Writing to file single_particle_free_space_0000660.h5
# Time step from 669 to 670 of 1000
# Writing step 670 to file
# Writing to file single_particle_free_space_0000670.h5
# Time step from 679 to 680 of 1000
# Writing step 680 to file
# Writing to file single_particle_free_space_0000680.h5
# Time step from 689 to 690 of 1000
# Writing step 690 to file
# Writing to file single_particle_free_space_0000690.h5
# Time step from 699 to 700 of 1000
# Writing step 700 to file
# Writing to file single_particle_free_space_0000700.h5
# Time step from 709 to 710 of 1000
# Writing step 710 to file
# Writing to file single_particle_free_space_0000710.h5
# Time step from 719 to 720 of 1000
# Writing step 720 to file
# Writing to file single_particle_free_space_0000720.h5
# Time step from 729 to 730 of 1000
# Writing step 730 to file
# Writing to file single_particle_free_space_0000730.h5
# Time step from 739 to 740 of 1000
# Writing step 740 to file
# Writing to file single_particle_free_space_0000740.h5
# Time step from 749 to 750 of 1000
# Writing step 750 to file
# Writing to file single_particle_free_space_0000750.h5
# Time step from 759 to 760 of 1000
# Writing step 760 to file
# Writing to file single_particle_free_space_0000760.h5
# Time step from 769 to 770 of 1000
# Writing step 770 to file
# Writing to file single_particle_free_space_0000770.h5
# Time step from 779 to 780 of 1000
# Writing step 780 to file
# Writing to file single_particle_free_space_0000780.h5
# Time step from 789 to 790 of 1000
# Writing step 790 to file
# Writing to file single_particle_free_space_0000790.h5
# Time step from 799 to 800 of 1000
# Writing step 800 to file
# Writing to file single_particle_free_space_0000800.h5
# Time step from 809 to 810 of 1000
# Writing step 810 to file
# Writing to file single_particle_free_space_0000810.h5
# Time step from 819 to 820 of 1000
# Writing step 820 to file
# Writing to file single_particle_free_space_0000820.h5
# Time step from 829 to 830 of 1000
# Writing step 830 to file
# Writing to file single_particle_free_space_0000830.h5
# Time step from 839 to 840 of 1000
# Writing step 840 to file
# Writing to file single_particle_free_space_0000840.h5
# Time step from 849 to 850 of 1000
# Writing step 850 to file
# Writing to file single_particle_free_space_0000850.h5
# Time step from 859 to 860 of 1000
# Writing step 860 to file
# Writing to file single_particle_free_space_0000860.h5
# Time step from 869 to 870 of 1000
# Writing step 870 to file
# Writing to file single_particle_free_space_0000870.h5
# Time step from 879 to 880 of 1000
# Writing step 880 to file
# Writing to file single_particle_free_space_0000880.h5
# Time step from 889 to 890 of 1000
# Writing step 890 to file
# Writing to file single_particle_free_space_0000890.h5
# Time step from 899 to 900 of 1000
# Writing step 900 to file
# Writing to file single_particle_free_space_0000900.h5
# Time step from 909 to 910 of 1000
# Writing step 910 to file
# Writing to file single_particle_free_space_0000910.h5
# Time step from 919 to 920 of 1000
# Writing step 920 to file
# Writing to file single_particle_free_space_0000920.h5
# Time step from 929 to 930 of 1000
# Writing step 930 to file
# Writing to file single_particle_free_space_0000930.h5
# Time step from 939 to 940 of 1000
# Writing step 940 to file
# Writing to file single_particle_free_space_0000940.h5
# Time step from 949 to 950 of 1000
# Writing step 950 to file
# Writing to file single_particle_free_space_0000950.h5
# Time step from 959 to 960 of 1000
# Writing step 960 to file
# Writing to file single_particle_free_space_0000960.h5
# Time step from 969 to 970 of 1000
# Writing step 970 to file
# Writing to file single_particle_free_space_0000970.h5
# Time step from 979 to 980 of 1000
# Writing step 980 to file
# Writing to file single_particle_free_space_0000980.h5
# Time step from 989 to 990 of 1000
# Writing step 990 to file
# Writing to file single_particle_free_space_0000990.h5
# Time step from 999 to 1000 of 1000
# Writing step 1000 to file
# Writing to file single_particle_free_space_0001000.h5

# %% [markdown]
# To run outside python (for example, C++ ef):

# %%
conf.export_to_fname('config.ini')

# %%
# !ef config.ini
# Out:
# Trying to guess input file type: config.ini
# ### Config:
# time_grid = TimeGridConf(total=6e-09, save_step=6e-11, step=6e-12)
# spatial_mesh = SpatialMeshConf(size=array([ 5.,  5., 15.]), step=array([0.5, 0.5, 1.5]))
# sources = [ParticleSourceConf(name='emit_single_particle', shape=Box(origin=array([0.1, 0.1, 0.1]), size=array([0.01, 0.01, 0.01])), initial_particles=1, particles_to_generate_each_step=0, momentum=array([6.00e-19, 6.00e-19, 1.77e-18]), temperature=0.0, charge=4.8e-10, mass=9.8e-28)]
# inner_regions = []
# output_file = OutputFileConf(prefix='single_particle_free_space_', suffix='.h5', format_='cpp')
# boundary_conditions = BoundaryConditionsConf(right=0.0, left=0.0, bottom=0.0, top=0.0, near=0.0, far=0.0)
# particle_interaction_model = ParticleInteractionModelConf(model='noninteracting')
# external_fields = []
#   Detected a Hermitian matrix
# Writing initial fields to file
# Writing to file single_particle_free_space_fieldsWithoutParticles.h5
# Writing step 0 to file
# Writing to file single_particle_free_space_0000000.h5
# Time step from 9 to 10 of 1000
# Writing step 10 to file
# Writing to file single_particle_free_space_0000010.h5
# Time step from 19 to 20 of 1000
# Writing step 20 to file
# Writing to file single_particle_free_space_0000020.h5
# Time step from 29 to 30 of 1000
# Writing step 30 to file
# Writing to file single_particle_free_space_0000030.h5
# Time step from 39 to 40 of 1000
# Writing step 40 to file
# Writing to file single_particle_free_space_0000040.h5
# Time step from 49 to 50 of 1000
# Writing step 50 to file
# Writing to file single_particle_free_space_0000050.h5
# Time step from 59 to 60 of 1000
# Writing step 60 to file
# Writing to file single_particle_free_space_0000060.h5
# Time step from 69 to 70 of 1000
# Writing step 70 to file
# Writing to file single_particle_free_space_0000070.h5
# Time step from 79 to 80 of 1000
# Writing step 80 to file
# Writing to file single_particle_free_space_0000080.h5
# Time step from 89 to 90 of 1000
# Writing step 90 to file
# Writing to file single_particle_free_space_0000090.h5
# Time step from 99 to 100 of 1000
# Writing step 100 to file
# Writing to file single_particle_free_space_0000100.h5
# Time step from 109 to 110 of 1000
# Writing step 110 to file
# Writing to file single_particle_free_space_0000110.h5
# Time step from 119 to 120 of 1000
# Writing step 120 to file
# Writing to file single_particle_free_space_0000120.h5
# Time step from 129 to 130 of 1000
# Writing step 130 to file
# Writing to file single_particle_free_space_0000130.h5
# Time step from 139 to 140 of 1000
# Writing step 140 to file
# Writing to file single_particle_free_space_0000140.h5
# Time step from 149 to 150 of 1000
# Writing step 150 to file
# Writing to file single_particle_free_space_0000150.h5
# Time step from 159 to 160 of 1000
# Writing step 160 to file
# Writing to file single_particle_free_space_0000160.h5
# Time step from 169 to 170 of 1000
# Writing step 170 to file
# Writing to file single_particle_free_space_0000170.h5
# Time step from 179 to 180 of 1000
# Writing step 180 to file
# Writing to file single_particle_free_space_0000180.h5
# Time step from 189 to 190 of 1000
# Writing step 190 to file
# Writing to file single_particle_free_space_0000190.h5
# Time step from 199 to 200 of 1000
# Writing step 200 to file
# Writing to file single_particle_free_space_0000200.h5
# Time step from 209 to 210 of 1000
# Writing step 210 to file
# Writing to file single_particle_free_space_0000210.h5
# Time step from 219 to 220 of 1000
# Writing step 220 to file
# Writing to file single_particle_free_space_0000220.h5
# Time step from 229 to 230 of 1000
# Writing step 230 to file
# Writing to file single_particle_free_space_0000230.h5
# Time step from 239 to 240 of 1000
# Writing step 240 to file
# Writing to file single_particle_free_space_0000240.h5
# Time step from 249 to 250 of 1000
# Writing step 250 to file
# Writing to file single_particle_free_space_0000250.h5
# Time step from 259 to 260 of 1000
# Writing step 260 to file
# Writing to file single_particle_free_space_0000260.h5
# Time step from 269 to 270 of 1000
# Writing step 270 to file
# Writing to file single_particle_free_space_0000270.h5
# Time step from 279 to 280 of 1000
# Writing step 280 to file
# Writing to file single_particle_free_space_0000280.h5
# Time step from 289 to 290 of 1000
# Writing step 290 to file
# Writing to file single_particle_free_space_0000290.h5
# Time step from 299 to 300 of 1000
# Writing step 300 to file
# Writing to file single_particle_free_space_0000300.h5
# Time step from 309 to 310 of 1000
# Writing step 310 to file
# Writing to file single_particle_free_space_0000310.h5
# Time step from 319 to 320 of 1000
# Writing step 320 to file
# Writing to file single_particle_free_space_0000320.h5
# Time step from 329 to 330 of 1000
# Writing step 330 to file
# Writing to file single_particle_free_space_0000330.h5
# Time step from 339 to 340 of 1000
# Writing step 340 to file
# Writing to file single_particle_free_space_0000340.h5
# Time step from 349 to 350 of 1000
# Writing step 350 to file
# Writing to file single_particle_free_space_0000350.h5
# Time step from 359 to 360 of 1000
# Writing step 360 to file
# Writing to file single_particle_free_space_0000360.h5
# Time step from 369 to 370 of 1000
# Writing step 370 to file
# Writing to file single_particle_free_space_0000370.h5
# Time step from 379 to 380 of 1000
# Writing step 380 to file
# Writing to file single_particle_free_space_0000380.h5
# Time step from 389 to 390 of 1000
# Writing step 390 to file
# Writing to file single_particle_free_space_0000390.h5
# Time step from 399 to 400 of 1000
# Writing step 400 to file
# Writing to file single_particle_free_space_0000400.h5
# Time step from 409 to 410 of 1000
# Writing step 410 to file
# Writing to file single_particle_free_space_0000410.h5
# Time step from 419 to 420 of 1000
# Writing step 420 to file
# Writing to file single_particle_free_space_0000420.h5
# Time step from 429 to 430 of 1000
# Writing step 430 to file
# Writing to file single_particle_free_space_0000430.h5
# Time step from 439 to 440 of 1000
# Writing step 440 to file
# Writing to file single_particle_free_space_0000440.h5
# Time step from 449 to 450 of 1000
# Writing step 450 to file
# Writing to file single_particle_free_space_0000450.h5
# Time step from 459 to 460 of 1000
# Writing step 460 to file
# Writing to file single_particle_free_space_0000460.h5
# Time step from 469 to 470 of 1000
# Writing step 470 to file
# Writing to file single_particle_free_space_0000470.h5
# Time step from 479 to 480 of 1000
# Writing step 480 to file
# Writing to file single_particle_free_space_0000480.h5
# Time step from 489 to 490 of 1000
# Writing step 490 to file
# Writing to file single_particle_free_space_0000490.h5
# Time step from 499 to 500 of 1000
# Writing step 500 to file
# Writing to file single_particle_free_space_0000500.h5
# Time step from 509 to 510 of 1000
# Writing step 510 to file
# Writing to file single_particle_free_space_0000510.h5
# Time step from 519 to 520 of 1000
# Writing step 520 to file
# Writing to file single_particle_free_space_0000520.h5
# Time step from 529 to 530 of 1000
# Writing step 530 to file
# Writing to file single_particle_free_space_0000530.h5
# Time step from 539 to 540 of 1000
# Writing step 540 to file
# Writing to file single_particle_free_space_0000540.h5
# Time step from 549 to 550 of 1000
# Writing step 550 to file
# Writing to file single_particle_free_space_0000550.h5
# Time step from 559 to 560 of 1000
# Writing step 560 to file
# Writing to file single_particle_free_space_0000560.h5
# Time step from 569 to 570 of 1000
# Writing step 570 to file
# Writing to file single_particle_free_space_0000570.h5
# Time step from 579 to 580 of 1000
# Writing step 580 to file
# Writing to file single_particle_free_space_0000580.h5
# Time step from 589 to 590 of 1000
# Writing step 590 to file
# Writing to file single_particle_free_space_0000590.h5
# Time step from 599 to 600 of 1000
# Writing step 600 to file
# Writing to file single_particle_free_space_0000600.h5
# Time step from 609 to 610 of 1000
# Writing step 610 to file
# Writing to file single_particle_free_space_0000610.h5
# Time step from 619 to 620 of 1000
# Writing step 620 to file
# Writing to file single_particle_free_space_0000620.h5
# Time step from 629 to 630 of 1000
# Writing step 630 to file
# Writing to file single_particle_free_space_0000630.h5
# Time step from 639 to 640 of 1000
# Writing step 640 to file
# Writing to file single_particle_free_space_0000640.h5
# Time step from 649 to 650 of 1000
# Writing step 650 to file
# Writing to file single_particle_free_space_0000650.h5
# Time step from 659 to 660 of 1000
# Writing step 660 to file
# Writing to file single_particle_free_space_0000660.h5
# Time step from 669 to 670 of 1000
# Writing step 670 to file
# Writing to file single_particle_free_space_0000670.h5
# Time step from 679 to 680 of 1000
# Writing step 680 to file
# Writing to file single_particle_free_space_0000680.h5
# Time step from 689 to 690 of 1000
# Writing step 690 to file
# Writing to file single_particle_free_space_0000690.h5
# Time step from 699 to 700 of 1000
# Writing step 700 to file
# Writing to file single_particle_free_space_0000700.h5
# Time step from 709 to 710 of 1000
# Writing step 710 to file
# Writing to file single_particle_free_space_0000710.h5
# Time step from 719 to 720 of 1000
# Writing step 720 to file
# Writing to file single_particle_free_space_0000720.h5
# Time step from 729 to 730 of 1000
# Writing step 730 to file
# Writing to file single_particle_free_space_0000730.h5
# Time step from 739 to 740 of 1000
# Writing step 740 to file
# Writing to file single_particle_free_space_0000740.h5
# Time step from 749 to 750 of 1000
# Writing step 750 to file
# Writing to file single_particle_free_space_0000750.h5
# Time step from 759 to 760 of 1000
# Writing step 760 to file
# Writing to file single_particle_free_space_0000760.h5
# Time step from 769 to 770 of 1000
# Writing step 770 to file
# Writing to file single_particle_free_space_0000770.h5
# Time step from 779 to 780 of 1000
# Writing step 780 to file
# Writing to file single_particle_free_space_0000780.h5
# Time step from 789 to 790 of 1000
# Writing step 790 to file
# Writing to file single_particle_free_space_0000790.h5
# Time step from 799 to 800 of 1000
# Writing step 800 to file
# Writing to file single_particle_free_space_0000800.h5
# Time step from 809 to 810 of 1000
# Writing step 810 to file
# Writing to file single_particle_free_space_0000810.h5
# Time step from 819 to 820 of 1000
# Writing step 820 to file
# Writing to file single_particle_free_space_0000820.h5
# Time step from 829 to 830 of 1000
# Writing step 830 to file
# Writing to file single_particle_free_space_0000830.h5
# Time step from 839 to 840 of 1000
# Writing step 840 to file
# Writing to file single_particle_free_space_0000840.h5
# Time step from 849 to 850 of 1000
# Writing step 850 to file
# Writing to file single_particle_free_space_0000850.h5
# Time step from 859 to 860 of 1000
# Writing step 860 to file
# Writing to file single_particle_free_space_0000860.h5
# Time step from 869 to 870 of 1000
# Writing step 870 to file
# Writing to file single_particle_free_space_0000870.h5
# Time step from 879 to 880 of 1000
# Writing step 880 to file
# Writing to file single_particle_free_space_0000880.h5
# Time step from 889 to 890 of 1000
# Writing step 890 to file
# Writing to file single_particle_free_space_0000890.h5
# Time step from 899 to 900 of 1000
# Writing step 900 to file
# Writing to file single_particle_free_space_0000900.h5
# Time step from 909 to 910 of 1000
# Writing step 910 to file
# Writing to file single_particle_free_space_0000910.h5
# Time step from 919 to 920 of 1000
# Writing step 920 to file
# Writing to file single_particle_free_space_0000920.h5
# Time step from 929 to 930 of 1000
# Writing step 930 to file
# Writing to file single_particle_free_space_0000930.h5
# Time step from 939 to 940 of 1000
# Writing step 940 to file
# Writing to file single_particle_free_space_0000940.h5
# Time step from 949 to 950 of 1000
# Writing step 950 to file
# Writing to file single_particle_free_space_0000950.h5
# Time step from 959 to 960 of 1000
# Writing step 960 to file
# Writing to file single_particle_free_space_0000960.h5
# Time step from 969 to 970 of 1000
# Writing step 970 to file
# Writing to file single_particle_free_space_0000970.h5
# Time step from 979 to 980 of 1000
# Writing step 980 to file
# Writing to file single_particle_free_space_0000980.h5
# Time step from 989 to 990 of 1000
# Writing step 990 to file
# Writing to file single_particle_free_space_0000990.h5
# Time step from 999 to 1000 of 1000
# Writing step 1000 to file
# Writing to file single_particle_free_space_0001000.h5

# %% [markdown]
# After the simulation finishes, a bunch of `*.h5` files emerge in the directory.

# %%
# !ls
# Out:
# 2d.png
# 3d.png
# config.ini
# kin_en.png
# plot.py
# single_particle_free_space_0000000.h5
# single_particle_free_space_0000010.h5
# single_particle_free_space_0000020.h5
# single_particle_free_space_0000030.h5
# single_particle_free_space_0000040.h5
# single_particle_free_space_0000050.h5
# single_particle_free_space_0000060.h5
# single_particle_free_space_0000070.h5
# single_particle_free_space_0000080.h5
# single_particle_free_space_0000090.h5
# single_particle_free_space_0000100.h5
# single_particle_free_space_0000110.h5
# single_particle_free_space_0000120.h5
# single_particle_free_space_0000130.h5
# single_particle_free_space_0000140.h5
# single_particle_free_space_0000150.h5
# single_particle_free_space_0000160.h5
# single_particle_free_space_0000170.h5
# single_particle_free_space_0000180.h5
# single_particle_free_space_0000190.h5
# single_particle_free_space_0000200.h5
# single_particle_free_space_0000210.h5
# single_particle_free_space_0000220.h5
# single_particle_free_space_0000230.h5
# single_particle_free_space_0000240.h5
# single_particle_free_space_0000250.h5
# single_particle_free_space_0000260.h5
# single_particle_free_space_0000270.h5
# single_particle_free_space_0000280.h5
# single_particle_free_space_0000290.h5
# single_particle_free_space_0000300.h5
# single_particle_free_space_0000310.h5
# single_particle_free_space_0000320.h5
# single_particle_free_space_0000330.h5
# single_particle_free_space_0000340.h5
# single_particle_free_space_0000350.h5
# single_particle_free_space_0000360.h5
# single_particle_free_space_0000370.h5
# single_particle_free_space_0000380.h5
# single_particle_free_space_0000390.h5
# single_particle_free_space_0000400.h5
# single_particle_free_space_0000410.h5
# single_particle_free_space_0000420.h5
# single_particle_free_space_0000430.h5
# single_particle_free_space_0000440.h5
# single_particle_free_space_0000450.h5
# single_particle_free_space_0000460.h5
# single_particle_free_space_0000470.h5
# single_particle_free_space_0000480.h5
# single_particle_free_space_0000490.h5
# single_particle_free_space_0000500.h5
# single_particle_free_space_0000510.h5
# single_particle_free_space_0000520.h5
# single_particle_free_space_0000530.h5
# single_particle_free_space_0000540.h5
# single_particle_free_space_0000550.h5
# single_particle_free_space_0000560.h5
# single_particle_free_space_0000570.h5
# single_particle_free_space_0000580.h5
# single_particle_free_space_0000590.h5
# single_particle_free_space_0000600.h5
# single_particle_free_space_0000610.h5
# single_particle_free_space_0000620.h5
# single_particle_free_space_0000630.h5
# single_particle_free_space_0000640.h5
# single_particle_free_space_0000650.h5
# single_particle_free_space_0000660.h5
# single_particle_free_space_0000670.h5
# single_particle_free_space_0000680.h5
# single_particle_free_space_0000690.h5
# single_particle_free_space_0000700.h5
# single_particle_free_space_0000710.h5
# single_particle_free_space_0000720.h5
# single_particle_free_space_0000730.h5
# single_particle_free_space_0000740.h5
# single_particle_free_space_0000750.h5
# single_particle_free_space_0000760.h5
# single_particle_free_space_0000770.h5
# single_particle_free_space_0000780.h5
# single_particle_free_space_0000790.h5
# single_particle_free_space_0000800.h5
# single_particle_free_space_0000810.h5
# single_particle_free_space_0000820.h5
# single_particle_free_space_0000830.h5
# single_particle_free_space_0000840.h5
# single_particle_free_space_0000850.h5
# single_particle_free_space_0000860.h5
# single_particle_free_space_0000870.h5
# single_particle_free_space_0000880.h5
# single_particle_free_space_0000890.h5
# single_particle_free_space_0000900.h5
# single_particle_free_space_0000910.h5
# single_particle_free_space_0000920.h5
# single_particle_free_space_0000930.h5
# single_particle_free_space_0000940.h5
# single_particle_free_space_0000950.h5
# single_particle_free_space_0000960.h5
# single_particle_free_space_0000970.h5
# single_particle_free_space_0000980.h5
# single_particle_free_space_0000990.h5
# single_particle_free_space_0001000.h5
# single_particle_free_space_fieldsWithoutParticles.h5
# single_particle_in_free_space.conf
# single_particle_in_free_space.ipynb

# %% [markdown]
# To open these files and glance over the results, an [Hdfview](https://support.hdfgroup.org/products/java/hdfview/) is a convenient tool.
# In this simulation, two places are of interest: `current time` and particle position
# and momentum at this time moment:
#
# <p align="center">
# <img src="https://github.com/epicf/ef/blob/dev/doc/figs/single_particle_in_free_space/hdfview_results.png?raw=true" alt="hdfview screenshot" width="600"/>
# </p>

# %% [markdown]
# Each created `h5`-file corresponds to a different time step.
# If we were able to extract time, position and momentum of the particle from each file, we could have obtained numerical trajectory, which could be compared to the analytical one.

# %% [markdown]
# Data extraction and plotting are accomplished by the accompanying [`plot.py`](https://github.com/epicf/ef/blob/master/examples/single_particle_in_free_space/plot.py) python script (see below). Its constituent parts are described further. The script produces a 3d plot and side views of the numerical and analytical trajectories. Besides, kinetic energies are compared.

# %%
import pandas as pd
import  glob
import h5py
import matplotlib.pyplot as plt 

def main():
    num = extract_num_trajectory_from_out_files()
    an = eval_an_trajectory_at_num_time_points( num )
    plot_trajectories( num , an )

def extract_num_trajectory_from_out_files():
    out_files = glob.glob("single_particle_free_space_[0-9][0-9][0-9][0-9][0-9][0-9][0-9].h5")

    num_trajectory = []
    for f in out_files:
        num_trajectory.append( extract_time_pos_mom( f ) )    

    num_trajectory = sorted([ x for x in num_trajectory if x ], key = lambda x: x[0])
    return pd.DataFrame.from_records(num_trajectory, columns=('t', 'x', 'y', 'z', 'px', 'py', 'pz'))
    
def extract_time_pos_mom( h5file ):
    h5 = h5py.File( h5file, mode="r")
    t = h5["/TimeGrid"].attrs["current_time"][0]
    t_pos_mom = ()
    if ( len(h5["/ParticleSources/emit_single_particle/particle_id"]) > 0 ):
        x = h5["/ParticleSources/emit_single_particle/position_x"][0]
        y = h5["/ParticleSources/emit_single_particle/position_y"][0]
        z = h5["/ParticleSources/emit_single_particle/position_z"][0]
        px = h5["/ParticleSources/emit_single_particle/momentum_x"][0]
        py = h5["/ParticleSources/emit_single_particle/momentum_y"][0]
        pz = h5["/ParticleSources/emit_single_particle/momentum_z"][0]
        t_pos_mom = (t, x, y, z, px, py, pz)
    h5.close()
    return( t_pos_mom )

def eval_an_trajectory_at_num_time_points( num_trajectory ):
    global particle_mass
    particle_mass, pos0, mom0 =  get_mass_and_initial_pos_and_mom()

    an_trajectory = []
    for t in num_trajectory.t:
        pos = coords( particle_mass, t, pos0, mom0 )
        mom = momenta( t, mom0 )
        an_trajectory.append([t] + list(pos) + list(mom))

    return pd.DataFrame.from_records(an_trajectory, columns=('t', 'x', 'y', 'z', 'px', 'py', 'pz'))

def get_mass_and_initial_pos_and_mom():
    initial_out_file = "single_particle_free_space_0000000.h5"
    h5 = h5py.File( initial_out_file, mode="r")
    m = h5["/ParticleSources/emit_single_particle"].attrs["mass"][0]
    x0 = h5["/ParticleSources/emit_single_particle/position_x"][0]
    y0 = h5["/ParticleSources/emit_single_particle/position_y"][0]
    z0 = h5["/ParticleSources/emit_single_particle/position_z"][0]
    px0 = h5["/ParticleSources/emit_single_particle/momentum_x"][0]
    py0 = h5["/ParticleSources/emit_single_particle/momentum_y"][0]
    pz0 = h5["/ParticleSources/emit_single_particle/momentum_z"][0]
    h5.close()
    return( m, [x0, y0, z0], [px0, py0, pz0] )


def momenta( t, mom0 ):    
    return mom0

def coords( m, t, pos0, mom0 ):
    pos = pos0 + mom0 / m * t
    return pos

def plot_trajectories( num , an ):
    plot_3d( num, an )
    plot_2d( num, an )
    plot_kin_en( num , an )

def plot_3d( num, an ):
    fig = plt.figure()
    ax = fig.gca( projection='3d' )
    ax.plot( num.x, num.z, num.y, 'b.', markersize = 12, label = "Num" )
    ax.plot( an.x, an.z, an.y,  'g-', linewidth = 3, label = "An" )
    ax.set_xlabel('X [cm]')
    ax.set_ylabel('Z [cm]')
    ax.set_zlabel('Y [cm]')
    plt.legend( loc = 'upper left', title="3d" )
    print( 'Saving 3d trajectory plot to "3d.png"' )
    plt.savefig('3d.png')
    plt.show()

def plot_2d( num, an ):
    plt.figure( figsize=( 16, 6 ) )
    plt.subplots_adjust( left = None, bottom = None,
                         right = None, top = None,
                         wspace = 0.4, hspace = None )
    #XY
    ax = plt.subplot(131)
    plt.plot( num.x, num.y,
              linestyle='', marker='o',
              label = "Num" )
    plt.plot( an.x, an.y,
              linestyle='-', marker='', lw = 2,
              label = "An" )
    ax.set_xlabel('X [cm]') 
    ax.set_ylabel('Y [cm]') 
    plt.legend( loc = 'upper left', title="XY" )
    #ZX
    ax = plt.subplot(132)
    plt.plot( num.z, num.x,
        linestyle='', marker='o',
        label = "Num" )
    plt.plot( an.z, an.x,
              linestyle='-', marker='', lw = 2,
              label = "An" )
    ax.set_xlabel('Z [cm]') 
    ax.set_ylabel('X [cm]') 
    plt.legend( loc = 'upper left', title="ZX" )
    #ZY
    ax = plt.subplot(133)
    plt.plot( num.z, num.y,
        linestyle='', marker='o',
        label = "Num" )
    plt.plot( an.z, an.y,
              linestyle='-', marker='', lw = 2,
              label = "An" )
    ax.set_xlabel('Z [cm]') 
    ax.set_ylabel('Y [cm]') 
    plt.legend( loc = 'upper left', title="ZY" )
    print( 'Saving 2d trajectory projection plots to "2d.png"' )
    plt.savefig('2d.png')
    plt.show()
    
def plot_kin_en( num , an ):
    global particle_mass
    E_num = (num.px**2 + num.py**2 + num.pz**2) / ( 2 * particle_mass )
    E_an = (an.px**2 + an.py**2 + an.pz**2) / ( 2 * particle_mass )
    t = num.t
    plt.figure()
    axes = plt.gca()
    axes.set_xlabel( "t [s]" )
    axes.set_ylabel( "E [erg]" )
    # axes.set_ylim( [min( E_an.min(), E_num.min() ),
    #                 max( E_an.max(), E_num.max() ) ] )
    line, = plt.plot( t, E_num, 'o' )
    line.set_label( "Num" )
    line, = plt.plot( t, E_an, ls = 'solid', lw = 3 )
    line.set_label( "An" )
    plt.legend( loc = 'upper right' )
    print( 'Saving kinetic energy comparison plot to "kin_en.png"' )
    plt.savefig('kin_en.png')
    plt.show()


main()
# Out:
# Saving 3d trajectory plot to "3d.png"
# Saving 2d trajectory projection plots to "2d.png"
# Saving kinetic energy comparison plot to "kin_en.png"

# %% [markdown]
# It can be seen, that numerical trajectory (points) coincides with the analytical (line) and that the energy is conserved during the simulation.

# %% [markdown]
# ### Plotting script
#
# The `main` function of the script does exactly what is described above: extracts numerical trajectory from the output files, evaluates analytical trajectory at the extracted time points and plots both numerical and analytical trajectories on the same axes.
#
# ```
# def main():
#     num = extract_num_trajectory_from_out_files()
#     an = eval_an_trajectory_at_num_time_points( num )
#     plot_trajectories( num , an )
# ```

# %% [markdown]
# It uses [h5py](http://www.h5py.org/) library to read from h5 files, [numpy](http://www.numpy.org/) to simplify working with arrays and [matplotlib](https://matplotlib.org/) to perform plotting of the trajectory.
#
# ```
# import os, glob
# import h5py
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# ```

# %% [markdown]
# Let's examine the function to obtain the numerical trajectory:
#
# ```
# def extract_num_trajectory_from_out_files():
#     out_files = find_necessary_out_files()                           # (*1)
#
#     num_trajectory = []
#     for f in out_files:
#         num_trajectory.append( extract_time_pos_mom( f ) )           # (*2)
#
#     num_trajectory = remove_empty_and_sort_by_time( num_trajectory ) # (*3)
#     num_trajectory = np.array( num_trajectory,                       # (*4)
#                                dtype=[('t','float'),
#                                       ('x','float'), ('y','float'), ('z','float'),
#                                       ('px','float'), ('py','float'),('pz','float')])
#     return( num_trajectory )
# ```
#
# (\*1): To extract data, first we find all `*.h5` files in the current directory.
# (\*2): Then the script iterates over them and extracts a relevant data from each one.
# (\*3): In the end of this process, `num_trajectory` array contains positions and velocities of particle at different
# time steps. In is convenient to sort it over time values.
# (\*4): After the previous step the numerical trajectory is in a format of a list of tuples:
# `[ (t, x, y, z, px, py, pz), ..... ]` . It is convenient to convert it into one of the `np.array` types to simplify further manipulations with it.

# %% [markdown]
# For analytical trajectory we need the initial position and momentum.
# They can be extracted from the first h5-file:
#
# ```
# def get_mass_and_initial_pos_and_mom():
#     initial_out_file = "single_particle_free_space_0000000.h5"
#     h5 = h5py.File( initial_out_file, mode="r")
#     m = h5["/ParticleSources/emit_single_particle"].attrs["mass"][0]
#     x0 = h5["/ParticleSources/emit_single_particle/position_x"][0]
#     y0 = h5["/ParticleSources/emit_single_particle/position_y"][0]
#     z0 = h5["/ParticleSources/emit_single_particle/position_z"][0]
#     px0 = h5["/ParticleSources/emit_single_particle/momentum_x"][0]
#     py0 = h5["/ParticleSources/emit_single_particle/momentum_y"][0]
#     pz0 = h5["/ParticleSources/emit_single_particle/momentum_z"][0]
#     h5.close()
#     return( m, x0, y0, z0, px0, py0, pz0 )
# ```

# %% [markdown]
# With this function, the analytical trajectory can be computed at the same
# time points as the numerical one:
#
# ```
# def eval_an_trajectory_at_num_time_points( num_trajectory ):
#     global particle_mass
#     particle_mass, x0, y0, z0, px0, py0, pz0 =  get_mass_and_initial_pos_and_mom()
#     #
#     an_trajectory = np.empty_like( num_trajectory )
#     for i, t in enumerate( num_trajectory['t'] ):
#         x, y, z = coords( particle_mass, t, x0, y0, z0, px0, py0, pz0 )
#         px, py, pz = momenta( t, px0, py0, pz0 )
#         an_trajectory[i] = ( t, x, y ,z, px, py, pz )
#     #
#     return( an_trajectory )
# ```

# %% [markdown]
# Finally, both numerical and analytical trajectories are plotted in 3d and side views.
# Kinetic energies are also compared.
#
# ```
# def plot_trajectories( num , an ):
#     plot_3d( num, an )
#     plot_2d( num, an )
#     plot_kin_en( num , an )
# ```
